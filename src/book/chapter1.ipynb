# %% [markdown]
# # Chapter 1: What is Machine Learning?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Example 1.1:

# %%
from sklearn.linear_model import LinearRegression
data_root = "https://github.com/ageron/data/raw/main/"
lifesat_data = pd.read_csv(data_root + "lifesat/lifesat.csv")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /usr/lib64/python3.14/urllib/request.py:1321, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1320 try:
# -> 1321     h.request(req.get_method(), req.selector, req.data, headers,
#    1322               encode_chunked=req.has_header('Transfer-encoding'))
#    1323 except OSError as err: # timeout error
#
# File /usr/lib64/python3.14/http/client.py:1367, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1366 """Send a complete request to the server."""
# -> 1367 self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib64/python3.14/http/client.py:1413, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1412     body = _encode(body, 'body')
# -> 1413 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
lifesat_data.head()

# %% [markdown]
# ### Visualize the data

# %%
lifesat_data.plot(kind="scatter", x="GDP per capita (USD)", y="Life satisfaction")

# %%
lifesat_data.plot(kind="kde", x="GDP per capita (USD)", y="Life satisfaction")

# %% [markdown]
# ### Train a linear regression model

# %%
X = lifesat_data[["GDP per capita (USD)"]]
Y = lifesat_data[["Life satisfaction"]]

# %%
lin_reg_model = LinearRegression()

# %%
lin_reg_model.fit(X, Y)

# %%
X_new = [[37655.2]] # Cyprus GDP per capita

# %%
Y_pred = lin_reg_model.predict(X_new)

# %%
Y_pred

# %% [markdown]
# ### Using K-Nearest Neighbors (KNN) for regression
#
# KNN is a non-parametric algorithm that can be used for both classification and regression. In KNN regression, the output is the average of the values of its k nearest neighbors.

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_reg_model = KNeighborsRegressor(n_neighbors=3)

# %%
knn_reg_model.fit(X, Y)

# %%
y_pred = knn_reg_model.predict(X_new)

# %%
y_pred
